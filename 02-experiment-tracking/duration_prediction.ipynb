# %%
# !python -V
# Out:
# Python 3.9.21

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression,LinearRegression,Lasso

# %%
from sklearn.metrics import mean_squared_error,root_mean_squared_error
import math
from sklearn.feature_extraction import DictVectorizer

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /home/codespace/anaconda3/envs/exp-tracking/lib/python3.9/site-packages (19.0.1)

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
#mlflow.set_experiment("nyc-taxi-experiment2")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/mlruns/2', creation_time=1742825619994, experiment_id='2', last_update_time=1742825619994, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df=pd.read_parquet(filename)
    df['duration']=df.lpep_dropoff_datetime-df.lpep_pickup_datetime
    df.duration=df.duration.apply(lambda x:x.total_seconds()/60)
    df=df[(df.duration>=1) & (df.duration<=60)]
    categorical=['PULocationID', 'DOLocationID']
    df[categorical]=df[categorical].astype(str)
    return df

# %%
df_train=read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val=read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train),len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO']=df_train['PULocationID']+"_"+df_train['DOLocationID']
df_val['PU_DO']=df_val['PULocationID']+"_"+df_val['DOLocationID']

# %%
categorical=['PU_DO']#'PULocationID', 'DOLocationID']
numerical=['trip_distance']
dv=DictVectorizer()
train_dicts=df_train[categorical+numerical].to_dict(orient="records")
X_train=dv.fit_transform(train_dicts)

val_dicts=df_val[categorical+numerical].to_dict(orient="records")
X_val=dv.transform(val_dicts)

# %%
target='duration'
y_train=df_train[target].values
y_val=df_val[target].values

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred=lr.predict(X_val)
root_mean_squared_error(y_val,y_pred)
# Out:
# 7.758715208009878

# %%
with open("./models/lin_reg.bin","wb") as fout:
    pickle.dump((dv,lr),fout)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer","mudathir")
    mlflow.log_param("train_data_path","./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("validation_data_path","./data/green_tripdata_2021-02.parquet")
    alpha=0.001
    mlflow.log_param("alpha",alpha)
    lr=Lasso(alpha)
    lr.fit(X_train, y_train)
    y_pred=lr.predict(X_val)
    rmse=root_mean_squared_error(y_val,y_pred)
    mlflow.log_metric("rmse",rmse)
    with open("./models/lin_reg_new.bin","wb") as fout:
        pickle.dump((dv,lr),fout)
    mlflow.log_artifact(local_path="./models/lin_reg_new.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb
from hyperopt import hp,fmin,tpe,Trials, STATUS_OK
from hyperopt.pyll import scope

# %%
train=xgb.DMatrix(X_train, label=y_train)
valid=xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model","xgboost_v2")
        mlflow.log_params(params)
        booster=xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
        y_pred=booster.predict(valid)
        rmse=root_mean_squared_error(y_val,y_pred)
        mlflow.log_metric("rmse",rmse)
        return {'loss': rmse, 'status':STATUS_OK}

# %%
search_space={
    "max_depth": scope.int(hp.quniform("max_depth",4,100,1)),
    "learning_rate": hp.loguniform("learning_rate",-3,0),
    "reg_alpha": hp.loguniform("reg_alpha",-5,-1),
    "reg_lambda": hp.loguniform("reg_lambda",-6,-1),
    "min_child_weight": hp.loguniform("min_child_weight",-1,3),
    "objective":'reg:linear',
    "seed":42
}

best_result=fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=20,
    trials=Trials())

# %%
best_params={"learning_rate":
0.09014190119550018,"max_depth":81,"min_child_weight":
2.0452967381046134,"objective":"reg:linear",
"reg_alpha":0.07820874638976405,
"reg_lambda":0.08033992266454794,"seed":42}

# %%
mlflow.xgboost.autolog()
booster=xgb.train(
            params=best_params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
# Out:
# 2025/03/25 11:37:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f51bf619b2dd443887259f966564f674', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow

# %%
mlflow.xgboost.autolog(disable=True)

# %%
from mlflow import MlflowClient
mlflow_tracking_uri="sqlite:///mlflow.db"
client=MlflowClient(mlflow_tracking_uri)

# %%
desired_run=client.get_run("707232543b814e74aca48be6c822f9af")
desired_run_params=desired_run.data.params
print(desired_run_params)
with mlflow.start_run():
    mlflow.set_tag("model","xgboost3")
    mlflow.log_params(desired_run_params)
    booster=xgb.train(
            params=desired_run_params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
    y_pred=booster.predict(valid)
    rmse=root_mean_squared_error(y_val,y_pred)
    mlflow.log_metric("rmse",rmse)
    with open("models/preprocessor.b","wb") as fout:
         pickle.dump(dv, fout)
    mlflow.log_artifact("models/preprocessor.b", "preprocessor")
    mlflow.xgboost.log_model(booster,artifact_path="models_mlflow")
# Out:
# {'learning_rate': '0.46400666326762463', 'max_depth': '70', 'min_child_weight': '3.7768059476285445', 'objective': 'reg:linear', 'reg_alpha': '0.02560203077527551', 'reg_lambda': '0.0027861679673304076', 'seed': '42'}
# /home/codespace/anaconda3/envs/exp-tracking/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [10:07:07] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.74318
# [1]	validation-rmse:7.35867
# [2]	validation-rmse:6.84527
# [3]	validation-rmse:6.65016
# [4]	validation-rmse:6.56333
# [5]	validation-rmse:6.51747
# [6]	validation-rmse:6.49565
# [7]	validation-rmse:6.48048
# [8]	validation-rmse:6.46901
# [9]	validation-rmse:6.46176
# [10]	validation-rmse:6.45761
# [11]	validation-rmse:6.45307
# [12]	validation-rmse:6.44842
# [13]	validation-rmse:6.44441
# [14]	validation-rmse:6.43924
# [15]	validation-rmse:6.43646
# [16]	validation-rmse:6.43316
# [17]	validation-rmse:6.43058
# [18]	validation-rmse:6.42857
# [19]	validation-rmse:6.42638
# [20]	validation-rmse:6.42000
# [21]	validation-rmse:6.41924
# [22]	validation-rmse:6.41659
# [23]	validation-rmse:6.41574
# [24]	validation-rmse:6.41517
# [25]	validation-rmse:6.41249
# [26]	validation-rmse:6.41139
# [27]	validation-rmse:6.41021
# [28]	validation-rmse:6.40816
# [29]	validation-rmse:6.40669
# [30]	validation-rmse:6.40535
# [31]	validation-rmse:6.40454
# [32]	validation-rmse:6.40363
# [33]	validation-rmse:6.40188
# [34]	validation-rmse:6.40064
# [35]	validation-rmse:6.40024
# [36]	validation-rmse:6.39978
# [37]	validation-rmse:6.39858
# [38]	validation-rmse:6.39687
# [39]	validation-rmse:6.39444
# [40]	validation-rmse:6.39387
# [41]	validation-rmse:6.39346
# [42]	validation-rmse:6.39171
# [43]	validation-rmse:6.39147
# [44]	validation-rmse:6.39060
# [45]	validation-rmse:6.38982
# [46]	validation-rmse:6.38730
# [47]	validation-rmse:6.38498
# [48]	validation-rmse:6.38491
# [49]	validation-rmse:6.38430
# [50]	validation-rmse:6.38460
# [51]	validation-rmse:6.38377
# [52]	validation-rmse:6.38290
# [53]	validation-rmse:6.38262
# [54]	validation-rmse:6.38197
# [55]	validation-rmse:6.38171
# [56]	validation-rmse:6.38198
# [57]	validation-rmse:6.38141
# [58]	validation-rmse:6.38140
# [59]	validation-rmse:6.38150
# [60]	validation-rmse:6.38166
# [61]	validation-rmse:6.38190
# [62]	validation-rmse:6.38156
# [63]	validation-rmse:6.38174
# [64]	validation-rmse:6.38255
# [65]	validation-rmse:6.38193
# [66]	validation-rmse:6.38069
# [67]	validation-rmse:6.37956
# [68]	validation-rmse:6.37910
# [69]	validation-rmse:6.37923
# [70]	validation-rmse:6.37739
# [71]	validation-rmse:6.37705
# [72]	validation-rmse:6.37613
# [73]	validation-rmse:6.37595
# [74]	validation-rmse:6.37614
# [75]	validation-rmse:6.37575
# [76]	validation-rmse:6.37452
# [77]	validation-rmse:6.37413
# [78]	validation-rmse:6.37406
# [79]	validation-rmse:6.37366
# [80]	validation-rmse:6.37389
# [81]	validation-rmse:6.37359
# [82]	validation-rmse:6.37392
# [83]	validation-rmse:6.37445
# [84]	validation-rmse:6.37441
# [85]	validation-rmse:6.37397
# [86]	validation-rmse:6.37336
# [87]	validation-rmse:6.37255
# [88]	validation-rmse:6.37229
# [89]	validation-rmse:6.37150
# [90]	validation-rmse:6.37160
# [91]	validation-rmse:6.37049
# [92]	validation-rmse:6.37030
# [93]	validation-rmse:6.37001
# [94]	validation-rmse:6.36994
# [95]	validation-rmse:6.36954
# [96]	validation-rmse:6.36974
# [97]	validation-rmse:6.36958
# [98]	validation-rmse:6.36932
# [99]	validation-rmse:6.36936
# [100]	validation-rmse:6.36899
# [101]	validation-rmse:6.36861
# [102]	validation-rmse:6.36823
# [103]	validation-rmse:6.36807
# [104]	validation-rmse:6.36798
# [105]	validation-rmse:6.36825
# [106]	validation-rmse:6.36723
# [107]	validation-rmse:6.36719
# [108]	validation-rmse:6.36756
# [109]	validation-rmse:6.36795
# [110]	validation-rmse:6.36784
# [111]	validation-rmse:6.36769
# [112]	validation-rmse:6.36762
# [113]	validation-rmse:6.36840
# [114]	validation-rmse:6.36813
# [115]	validation-rmse:6.36768
# [116]	validation-rmse:6.36786
# [117]	validation-rmse:6.36765
# [118]	validation-rmse:6.36733
# [119]	validation-rmse:6.36672
# [120]	validation-rmse:6.36676
# [121]	validation-rmse:6.36708
# [122]	validation-rmse:6.36633
# [123]	validation-rmse:6.36620
# [124]	validation-rmse:6.36590
# [125]	validation-rmse:6.36607
# [126]	validation-rmse:6.36572
# [127]	validation-rmse:6.36562
# [128]	validation-rmse:6.36548
# [129]	validation-rmse:6.36555
# [130]	validation-rmse:6.36537
# [131]	validation-rmse:6.36537
# [132]	validation-rmse:6.36568
# [133]	validation-rmse:6.36617
# [134]	validation-rmse:6.36460
# [135]	validation-rmse:6.36468
# [136]	validation-rmse:6.36512
# [137]	validation-rmse:6.36522
# [138]	validation-rmse:6.36473
# [139]	validation-rmse:6.36501
# [140]	validation-rmse:6.36547
# [141]	validation-rmse:6.36537
# [142]	validation-rmse:6.36508
# [143]	validation-rmse:6.36518
# [144]	validation-rmse:6.36539
# [145]	validation-rmse:6.36534
# [146]	validation-rmse:6.36534
# [147]	validation-rmse:6.36523
# [148]	validation-rmse:6.36486
# [149]	validation-rmse:6.36479
# [150]	validation-rmse:6.36446
# [151]	validation-rmse:6.36486
# [152]	validation-rmse:6.36482
# [153]	validation-rmse:6.36445
# [154]	validation-rmse:6.36465
# [155]	validation-rmse:6.36459
# [156]	validation-rmse:6.36528
# [157]	validation-rmse:6.36506
# [158]	validation-rmse:6.36541
# [159]	validation-rmse:6.36492
# [160]	validation-rmse:6.36548
# [161]	validation-rmse:6.36519
# [162]	validation-rmse:6.36518
# [163]	validation-rmse:6.36520
# [164]	validation-rmse:6.36625
# [165]	validation-rmse:6.36654
# [166]	validation-rmse:6.36605
# [167]	validation-rmse:6.36613
# [168]	validation-rmse:6.36699
# [169]	validation-rmse:6.36807
# [170]	validation-rmse:6.36818
# [171]	validation-rmse:6.36870
# [172]	validation-rmse:6.36846
# [173]	validation-rmse:6.36858
# [174]	validation-rmse:6.36866
# [175]	validation-rmse:6.36904
# [176]	validation-rmse:6.36866
# [177]	validation-rmse:6.36821
# [178]	validation-rmse:6.36788
# [179]	validation-rmse:6.36775
# [180]	validation-rmse:6.36774
# [181]	validation-rmse:6.36794
# [182]	validation-rmse:6.36764
# [183]	validation-rmse:6.36735
# [184]	validation-rmse:6.36778
# [185]	validation-rmse:6.36785
# [186]	validation-rmse:6.36809
# [187]	validation-rmse:6.36847
# [188]	validation-rmse:6.36816
# [189]	validation-rmse:6.36817
# [190]	validation-rmse:6.36841
# [191]	validation-rmse:6.36819
# [192]	validation-rmse:6.36825
# [193]	validation-rmse:6.36821
# [194]	validation-rmse:6.36837
# [195]	validation-rmse:6.36791
# [196]	validation-rmse:6.36771
# [197]	validation-rmse:6.36796
# [198]	validation-rmse:6.36750
# [199]	validation-rmse:6.36821
# [200]	validation-rmse:6.36824
# [201]	validation-rmse:6.36790
# [202]	validation-rmse:6.36747
# /home/codespace/anaconda3/envs/exp-tracking/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [10:08:21] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/03/29 10:08:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
with mlflow.start_run():
    best_params={"learning_rate":
        0.09014190119550018,"max_depth":81,"min_child_weight":
        2.0452967381046134,"objective":"reg:linear",
        "reg_alpha":0.07820874638976405,
        "reg_lambda":0.08033992266454794,"seed":42}
    mlflow.log_params(best_params)
    booster=xgb.train(
            params=best_params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
    y_pred=booster.predict(valid)
    rmse=root_mean_squared_error(y_val,y_pred)
    mlflow.log_metric("rmse",rmse)
    with open("models/preprocessor.b","wb") as fout:
        pickle.dump(dv, fout)
    mlflow.log_artifact("models/preprocessor.b", "preprocessor")
    mlflow.xgboost.log_model(booster,artifact_path="models_mlflow")
# Out:
# /home/codespace/anaconda3/envs/exp-tracking/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [05:13:42] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.47766
# [1]	validation-rmse:10.82777
# [2]	validation-rmse:10.25528
# [3]	validation-rmse:9.75138
# [4]	validation-rmse:9.31152
# [5]	validation-rmse:8.92713
# [6]	validation-rmse:8.59196
# [7]	validation-rmse:8.30042
# [8]	validation-rmse:8.04990
# [9]	validation-rmse:7.83213
# [10]	validation-rmse:7.64566
# [11]	validation-rmse:7.48518
# [12]	validation-rmse:7.34754
# [13]	validation-rmse:7.22885
# [14]	validation-rmse:7.12675
# [15]	validation-rmse:7.03905
# [16]	validation-rmse:6.96432
# [17]	validation-rmse:6.89944
# [18]	validation-rmse:6.84370
# [19]	validation-rmse:6.79371
# [20]	validation-rmse:6.75060
# [21]	validation-rmse:6.71443
# [22]	validation-rmse:6.68179
# [23]	validation-rmse:6.65457
# [24]	validation-rmse:6.63091
# [25]	validation-rmse:6.60932
# [26]	validation-rmse:6.59090
# [27]	validation-rmse:6.57441
# [28]	validation-rmse:6.55938
# [29]	validation-rmse:6.54532
# [30]	validation-rmse:6.53304
# [31]	validation-rmse:6.52349
# [32]	validation-rmse:6.51423
# [33]	validation-rmse:6.50551
# [34]	validation-rmse:6.49804
# [35]	validation-rmse:6.49153
# [36]	validation-rmse:6.48531
# [37]	validation-rmse:6.47995
# [38]	validation-rmse:6.47503
# [39]	validation-rmse:6.47054
# [40]	validation-rmse:6.46653
# [41]	validation-rmse:6.46262
# [42]	validation-rmse:6.45895
# [43]	validation-rmse:6.45518
# [44]	validation-rmse:6.45280
# [45]	validation-rmse:6.44967
# [46]	validation-rmse:6.44722
# [47]	validation-rmse:6.44408
# [48]	validation-rmse:6.44153
# [49]	validation-rmse:6.43948
# [50]	validation-rmse:6.43734
# [51]	validation-rmse:6.43533
# [52]	validation-rmse:6.43349
# [53]	validation-rmse:6.43186
# [54]	validation-rmse:6.43006
# [55]	validation-rmse:6.42822
# [56]	validation-rmse:6.42623
# [57]	validation-rmse:6.42476
# [58]	validation-rmse:6.42355
# [59]	validation-rmse:6.42285
# [60]	validation-rmse:6.42193
# [61]	validation-rmse:6.42064
# [62]	validation-rmse:6.42006
# [63]	validation-rmse:6.41820
# [64]	validation-rmse:6.41768
# [65]	validation-rmse:6.41638
# [66]	validation-rmse:6.41537
# [67]	validation-rmse:6.41484
# [68]	validation-rmse:6.41435
# [69]	validation-rmse:6.41359
# [70]	validation-rmse:6.41254
# [71]	validation-rmse:6.41203
# [72]	validation-rmse:6.41038
# [73]	validation-rmse:6.40990
# [74]	validation-rmse:6.40916
# [75]	validation-rmse:6.40799
# [76]	validation-rmse:6.40711
# [77]	validation-rmse:6.40584
# [78]	validation-rmse:6.40514
# [79]	validation-rmse:6.40444
# [80]	validation-rmse:6.40379
# [81]	validation-rmse:6.40297
# [82]	validation-rmse:6.40229
# [83]	validation-rmse:6.40173
# [84]	validation-rmse:6.40087
# [85]	validation-rmse:6.40053
# [86]	validation-rmse:6.40002
# [87]	validation-rmse:6.39955
# [88]	validation-rmse:6.39909
# [89]	validation-rmse:6.39838
# [90]	validation-rmse:6.39784
# [91]	validation-rmse:6.39706
# [92]	validation-rmse:6.39673
# [93]	validation-rmse:6.39565
# [94]	validation-rmse:6.39483
# [95]	validation-rmse:6.39440
# [96]	validation-rmse:6.39401
# [97]	validation-rmse:6.39358
# [98]	validation-rmse:6.39341
# [99]	validation-rmse:6.39274
# [100]	validation-rmse:6.39240
# [101]	validation-rmse:6.39193
# [102]	validation-rmse:6.39142
# [103]	validation-rmse:6.39098
# [104]	validation-rmse:6.39058
# [105]	validation-rmse:6.39019
# [106]	validation-rmse:6.38956
# [107]	validation-rmse:6.38931
# [108]	validation-rmse:6.38877
# [109]	validation-rmse:6.38834
# [110]	validation-rmse:6.38771
# [111]	validation-rmse:6.38732
# [112]	validation-rmse:6.38685
# [113]	validation-rmse:6.38662
# [114]	validation-rmse:6.38616
# [115]	validation-rmse:6.38599
# [116]	validation-rmse:6.38567
# [117]	validation-rmse:6.38544
# [118]	validation-rmse:6.38501
# [119]	validation-rmse:6.38469
# [120]	validation-rmse:6.38430
# [121]	validation-rmse:6.38396
# [122]	validation-rmse:6.38353
# [123]	validation-rmse:6.38278
# [124]	validation-rmse:6.38258
# [125]	validation-rmse:6.38238
# [126]	validation-rmse:6.38211
# [127]	validation-rmse:6.38157
# [128]	validation-rmse:6.38114
# [129]	validation-rmse:6.38075
# [130]	validation-rmse:6.38055
# [131]	validation-rmse:6.38011
# [132]	validation-rmse:6.37996
# [133]	validation-rmse:6.37957
# [134]	validation-rmse:6.37946
# [135]	validation-rmse:6.37901
# [136]	validation-rmse:6.37881
# [137]	validation-rmse:6.37865
# [138]	validation-rmse:6.37821
# [139]	validation-rmse:6.37796
# [140]	validation-rmse:6.37766
# [141]	validation-rmse:6.37747
# [142]	validation-rmse:6.37694
# [143]	validation-rmse:6.37676
# [144]	validation-rmse:6.37653
# [145]	validation-rmse:6.37613
# [146]	validation-rmse:6.37590
# [147]	validation-rmse:6.37563
# [148]	validation-rmse:6.37512
# [149]	validation-rmse:6.37483
# [150]	validation-rmse:6.37452
# [151]	validation-rmse:6.37427
# [152]	validation-rmse:6.37388
# [153]	validation-rmse:6.37368
# [154]	validation-rmse:6.37324
# [155]	validation-rmse:6.37305
# [156]	validation-rmse:6.37274
# [157]	validation-rmse:6.37242
# [158]	validation-rmse:6.37232
# [159]	validation-rmse:6.37208
# [160]	validation-rmse:6.37194
# [161]	validation-rmse:6.37179
# [162]	validation-rmse:6.37135
# [163]	validation-rmse:6.37111
# [164]	validation-rmse:6.37094
# [165]	validation-rmse:6.37053
# [166]	validation-rmse:6.37038
# [167]	validation-rmse:6.37010
# [168]	validation-rmse:6.36982
# [169]	validation-rmse:6.36974
# [170]	validation-rmse:6.36931
# [171]	validation-rmse:6.36906
# [172]	validation-rmse:6.36892
# [173]	validation-rmse:6.36814
# [174]	validation-rmse:6.36778
# [175]	validation-rmse:6.36731
# [176]	validation-rmse:6.36706
# [177]	validation-rmse:6.36680
# [178]	validation-rmse:6.36656
# [179]	validation-rmse:6.36650
# [180]	validation-rmse:6.36627
# [181]	validation-rmse:6.36596
# [182]	validation-rmse:6.36575
# [183]	validation-rmse:6.36529
# [184]	validation-rmse:6.36520
# [185]	validation-rmse:6.36505
# [186]	validation-rmse:6.36497
# [187]	validation-rmse:6.36469
# [188]	validation-rmse:6.36438
# [189]	validation-rmse:6.36416
# [190]	validation-rmse:6.36394
# [191]	validation-rmse:6.36378
# [192]	validation-rmse:6.36358
# [193]	validation-rmse:6.36335
# [194]	validation-rmse:6.36318
# [195]	validation-rmse:6.36316
# [196]	validation-rmse:6.36289
# [197]	validation-rmse:6.36250
# [198]	validation-rmse:6.36228
# [199]	validation-rmse:6.36210
# [200]	validation-rmse:6.36181
# [201]	validation-rmse:6.36154
# [202]	validation-rmse:6.36145
# [203]	validation-rmse:6.36116
# [204]	validation-rmse:6.36069
# [205]	validation-rmse:6.36045
# [206]	validation-rmse:6.36029
# [207]	validation-rmse:6.35995
# [208]	validation-rmse:6.35975
# [209]	validation-rmse:6.35944
# [210]	validation-rmse:6.35932
# [211]	validation-rmse:6.35918
# [212]	validation-rmse:6.35925
# [213]	validation-rmse:6.35912
# [214]	validation-rmse:6.35868
# [215]	validation-rmse:6.35845
# [216]	validation-rmse:6.35839
# [217]	validation-rmse:6.35803
# [218]	validation-rmse:6.35789
# [219]	validation-rmse:6.35759
# [220]	validation-rmse:6.35752
# [221]	validation-rmse:6.35728
# [222]	validation-rmse:6.35717
# [223]	validation-rmse:6.35710
# [224]	validation-rmse:6.35683
# [225]	validation-rmse:6.35664
# [226]	validation-rmse:6.35642
# [227]	validation-rmse:6.35633
# [228]	validation-rmse:6.35629
# [229]	validation-rmse:6.35568
# [230]	validation-rmse:6.35549
# [231]	validation-rmse:6.35553
# [232]	validation-rmse:6.35556
# [233]	validation-rmse:6.35522
# [234]	validation-rmse:6.35490
# [235]	validation-rmse:6.35487
# [236]	validation-rmse:6.35474
# [237]	validation-rmse:6.35477
# [238]	validation-rmse:6.35437
# [239]	validation-rmse:6.35428
# [240]	validation-rmse:6.35386
# [241]	validation-rmse:6.35382
# [242]	validation-rmse:6.35358
# [243]	validation-rmse:6.35351
# [244]	validation-rmse:6.35328
# [245]	validation-rmse:6.35316
# [246]	validation-rmse:6.35304
# [247]	validation-rmse:6.35290
# [248]	validation-rmse:6.35271
# [249]	validation-rmse:6.35255
# [250]	validation-rmse:6.35240
# [251]	validation-rmse:6.35239
# [252]	validation-rmse:6.35220
# [253]	validation-rmse:6.35199
# [254]	validation-rmse:6.35180
# [255]	validation-rmse:6.35167
# [256]	validation-rmse:6.35161
# [257]	validation-rmse:6.35152
# [258]	validation-rmse:6.35141
# [259]	validation-rmse:6.35111
# [260]	validation-rmse:6.35110
# [261]	validation-rmse:6.35089
# [262]	validation-rmse:6.35073
# [263]	validation-rmse:6.35066
# [264]	validation-rmse:6.35069
# [265]	validation-rmse:6.35059
# [266]	validation-rmse:6.35076
# [267]	validation-rmse:6.35067
# [268]	validation-rmse:6.35056
# [269]	validation-rmse:6.35041
# [270]	validation-rmse:6.34998
# [271]	validation-rmse:6.35012
# [272]	validation-rmse:6.35009
# [273]	validation-rmse:6.34996
# [274]	validation-rmse:6.34986
# [275]	validation-rmse:6.34986
# [276]	validation-rmse:6.34979
# [277]	validation-rmse:6.34958
# [278]	validation-rmse:6.34932
# [279]	validation-rmse:6.34937
# [280]	validation-rmse:6.34926
# [281]	validation-rmse:6.34917
# [282]	validation-rmse:6.34910
# [283]	validation-rmse:6.34919
# [284]	validation-rmse:6.34906
# [285]	validation-rmse:6.34894
# [286]	validation-rmse:6.34885
# [287]	validation-rmse:6.34863
# [288]	validation-rmse:6.34854
# [289]	validation-rmse:6.34839
# [290]	validation-rmse:6.34826
# [291]	validation-rmse:6.34820
# [292]	validation-rmse:6.34813
# [293]	validation-rmse:6.34797
# [294]	validation-rmse:6.34791
# [295]	validation-rmse:6.34789
# [296]	validation-rmse:6.34764
# [297]	validation-rmse:6.34760
# [298]	validation-rmse:6.34732
# [299]	validation-rmse:6.34711
# [300]	validation-rmse:6.34711
# [301]	validation-rmse:6.34686
# [302]	validation-rmse:6.34677
# [303]	validation-rmse:6.34663
# [304]	validation-rmse:6.34656
# [305]	validation-rmse:6.34643
# [306]	validation-rmse:6.34636
# [307]	validation-rmse:6.34628
# [308]	validation-rmse:6.34640
# [309]	validation-rmse:6.34647
# [310]	validation-rmse:6.34644
# [311]	validation-rmse:6.34661
# [312]	validation-rmse:6.34655
# [313]	validation-rmse:6.34644
# [314]	validation-rmse:6.34612
# [315]	validation-rmse:6.34599
# [316]	validation-rmse:6.34574
# [317]	validation-rmse:6.34576
# [318]	validation-rmse:6.34550
# [319]	validation-rmse:6.34539
# [320]	validation-rmse:6.34534
# [321]	validation-rmse:6.34538
# [322]	validation-rmse:6.34536
# [323]	validation-rmse:6.34537
# [324]	validation-rmse:6.34529
# [325]	validation-rmse:6.34530
# [326]	validation-rmse:6.34532
# [327]	validation-rmse:6.34503
# [328]	validation-rmse:6.34498
# [329]	validation-rmse:6.34494
# [330]	validation-rmse:6.34491
# [331]	validation-rmse:6.34482
# [332]	validation-rmse:6.34475
# [333]	validation-rmse:6.34451
# [334]	validation-rmse:6.34446
# [335]	validation-rmse:6.34448
# [336]	validation-rmse:6.34435
# [337]	validation-rmse:6.34420
# [338]	validation-rmse:6.34421
# [339]	validation-rmse:6.34429
# [340]	validation-rmse:6.34403
# [341]	validation-rmse:6.34412
# [342]	validation-rmse:6.34405
# [343]	validation-rmse:6.34347
# [344]	validation-rmse:6.34346
# [345]	validation-rmse:6.34339
# [346]	validation-rmse:6.34333
# [347]	validation-rmse:6.34306
# [348]	validation-rmse:6.34320
# [349]	validation-rmse:6.34292
# [350]	validation-rmse:6.34310
# [351]	validation-rmse:6.34311
# [352]	validation-rmse:6.34299
# [353]	validation-rmse:6.34295
# [354]	validation-rmse:6.34306
# [355]	validation-rmse:6.34303
# [356]	validation-rmse:6.34283
# [357]	validation-rmse:6.34258
# [358]	validation-rmse:6.34254
# [359]	validation-rmse:6.34253
# [360]	validation-rmse:6.34253
# [361]	validation-rmse:6.34240
# [362]	validation-rmse:6.34249
# [363]	validation-rmse:6.34242
# [364]	validation-rmse:6.34243
# [365]	validation-rmse:6.34249
# [366]	validation-rmse:6.34260
# [367]	validation-rmse:6.34248
# [368]	validation-rmse:6.34244
# [369]	validation-rmse:6.34214
# [370]	validation-rmse:6.34227
# [371]	validation-rmse:6.34224
# [372]	validation-rmse:6.34222
# [373]	validation-rmse:6.34213
# [374]	validation-rmse:6.34210
# [375]	validation-rmse:6.34193
# [376]	validation-rmse:6.34195
# [377]	validation-rmse:6.34186
# [378]	validation-rmse:6.34189
# [379]	validation-rmse:6.34174
# [380]	validation-rmse:6.34169
# [381]	validation-rmse:6.34158
# [382]	validation-rmse:6.34166
# [383]	validation-rmse:6.34178
# [384]	validation-rmse:6.34177
# [385]	validation-rmse:6.34175
# [386]	validation-rmse:6.34168
# [387]	validation-rmse:6.34172
# [388]	validation-rmse:6.34137
# [389]	validation-rmse:6.34131
# [390]	validation-rmse:6.34116
# [391]	validation-rmse:6.34082
# [392]	validation-rmse:6.34070
# [393]	validation-rmse:6.34057
# [394]	validation-rmse:6.34058
# [395]	validation-rmse:6.34049
# [396]	validation-rmse:6.34009
# [397]	validation-rmse:6.34022
# [398]	validation-rmse:6.34025
# [399]	validation-rmse:6.33994
# [400]	validation-rmse:6.34007
# [401]	validation-rmse:6.33998
# [402]	validation-rmse:6.33968
# [403]	validation-rmse:6.33971
# [404]	validation-rmse:6.33971
# [405]	validation-rmse:6.33978
# [406]	validation-rmse:6.33977
# [407]	validation-rmse:6.33964
# [408]	validation-rmse:6.33960
# [409]	validation-rmse:6.33952
# [410]	validation-rmse:6.33950
# [411]	validation-rmse:6.33944
# [412]	validation-rmse:6.33936
# [413]	validation-rmse:6.33926
# [414]	validation-rmse:6.33921
# [415]	validation-rmse:6.33934
# [416]	validation-rmse:6.33939
# [417]	validation-rmse:6.33937
# [418]	validation-rmse:6.33932
# [419]	validation-rmse:6.33935
# [420]	validation-rmse:6.33902
# [421]	validation-rmse:6.33914
# [422]	validation-rmse:6.33919
# [423]	validation-rmse:6.33917
# [424]	validation-rmse:6.33870
# [425]	validation-rmse:6.33886
# [426]	validation-rmse:6.33883
# [427]	validation-rmse:6.33830
# [428]	validation-rmse:6.33823
# [429]	validation-rmse:6.33817
# [430]	validation-rmse:6.33817
# [431]	validation-rmse:6.33813
# [432]	validation-rmse:6.33809
# [433]	validation-rmse:6.33809
# [434]	validation-rmse:6.33805
# [435]	validation-rmse:6.33799
# [436]	validation-rmse:6.33789
# [437]	validation-rmse:6.33761
# [438]	validation-rmse:6.33746
# [439]	validation-rmse:6.33740
# [440]	validation-rmse:6.33712
# [441]	validation-rmse:6.33711
# [442]	validation-rmse:6.33695
# [443]	validation-rmse:6.33692
# [444]	validation-rmse:6.33655
# [445]	validation-rmse:6.33612
# [446]	validation-rmse:6.33616
# [447]	validation-rmse:6.33607
# [448]	validation-rmse:6.33610
# [449]	validation-rmse:6.33583
# [450]	validation-rmse:6.33538
# [451]	validation-rmse:6.33525
# [452]	validation-rmse:6.33538
# [453]	validation-rmse:6.33531
# [454]	validation-rmse:6.33534
# [455]	validation-rmse:6.33528
# [456]	validation-rmse:6.33526
# [457]	validation-rmse:6.33486
# [458]	validation-rmse:6.33501
# [459]	validation-rmse:6.33498
# [460]	validation-rmse:6.33476
# [461]	validation-rmse:6.33481
# [462]	validation-rmse:6.33473
# [463]	validation-rmse:6.33449
# [464]	validation-rmse:6.33452
# [465]	validation-rmse:6.33439
# [466]	validation-rmse:6.33427
# [467]	validation-rmse:6.33420
# [468]	validation-rmse:6.33409
# [469]	validation-rmse:6.33397
# [470]	validation-rmse:6.33404
# [471]	validation-rmse:6.33404
# [472]	validation-rmse:6.33389
# [473]	validation-rmse:6.33395
# [474]	validation-rmse:6.33384
# [475]	validation-rmse:6.33363
# [476]	validation-rmse:6.33359
# [477]	validation-rmse:6.33350
# [478]	validation-rmse:6.33349
# [479]	validation-rmse:6.33337
# [480]	validation-rmse:6.33328
# [481]	validation-rmse:6.33323
# [482]	validation-rmse:6.33320
# [483]	validation-rmse:6.33311
# [484]	validation-rmse:6.33314
# [485]	validation-rmse:6.33316
# [486]	validation-rmse:6.33301
# [487]	validation-rmse:6.33286
# [488]	validation-rmse:6.33293
# [489]	validation-rmse:6.33297
# [490]	validation-rmse:6.33300
# [491]	validation-rmse:6.33296
# [492]	validation-rmse:6.33280
# [493]	validation-rmse:6.33279
# [494]	validation-rmse:6.33277
# [495]	validation-rmse:6.33275
# [496]	validation-rmse:6.33273
# [497]	validation-rmse:6.33269
# [498]	validation-rmse:6.33257
# [499]	validation-rmse:6.33263
# [500]	validation-rmse:6.33266
# [501]	validation-rmse:6.33256
# [502]	validation-rmse:6.33252
# [503]	validation-rmse:6.33251
# [504]	validation-rmse:6.33230
# [505]	validation-rmse:6.33225
# [506]	validation-rmse:6.33188
# [507]	validation-rmse:6.33199
# [508]	validation-rmse:6.33203
# [509]	validation-rmse:6.33199
# [510]	validation-rmse:6.33202
# [511]	validation-rmse:6.33199
# [512]	validation-rmse:6.33198
# [513]	validation-rmse:6.33187
# [514]	validation-rmse:6.33189
# [515]	validation-rmse:6.33192
# [516]	validation-rmse:6.33180
# [517]	validation-rmse:6.33164
# [518]	validation-rmse:6.33162
# [519]	validation-rmse:6.33154
# [520]	validation-rmse:6.33155
# [521]	validation-rmse:6.33141
# [522]	validation-rmse:6.33131
# [523]	validation-rmse:6.33126
# [524]	validation-rmse:6.33121
# [525]	validation-rmse:6.33108
# [526]	validation-rmse:6.33100
# [527]	validation-rmse:6.33104
# [528]	validation-rmse:6.33099
# [529]	validation-rmse:6.33110
# [530]	validation-rmse:6.33118
# [531]	validation-rmse:6.33134
# [532]	validation-rmse:6.33127
# [533]	validation-rmse:6.33123
# [534]	validation-rmse:6.33117
# [535]	validation-rmse:6.33105
# [536]	validation-rmse:6.33114
# [537]	validation-rmse:6.33106
# [538]	validation-rmse:6.33104
# [539]	validation-rmse:6.33100
# [540]	validation-rmse:6.33097
# [541]	validation-rmse:6.33068
# [542]	validation-rmse:6.33067
# [543]	validation-rmse:6.33068
# [544]	validation-rmse:6.33074
# [545]	validation-rmse:6.33062
# [546]	validation-rmse:6.33064
# [547]	validation-rmse:6.33060
# [548]	validation-rmse:6.33060
# [549]	validation-rmse:6.33070
# [550]	validation-rmse:6.33072
# [551]	validation-rmse:6.33066
# [552]	validation-rmse:6.33065
# [553]	validation-rmse:6.33063
# [554]	validation-rmse:6.33067
# [555]	validation-rmse:6.33052
# [556]	validation-rmse:6.33066
# [557]	validation-rmse:6.33065
# [558]	validation-rmse:6.33064
# [559]	validation-rmse:6.33050
# [560]	validation-rmse:6.33053
# [561]	validation-rmse:6.33051
# [562]	validation-rmse:6.33055
# [563]	validation-rmse:6.33052
# [564]	validation-rmse:6.33059
# [565]	validation-rmse:6.33071
# [566]	validation-rmse:6.33069
# [567]	validation-rmse:6.33075
# [568]	validation-rmse:6.33063
# [569]	validation-rmse:6.33049
# [570]	validation-rmse:6.33046
# [571]	validation-rmse:6.33043
# [572]	validation-rmse:6.33041
# [573]	validation-rmse:6.33035
# [574]	validation-rmse:6.33019
# [575]	validation-rmse:6.33021
# [576]	validation-rmse:6.33026
# [577]	validation-rmse:6.33010
# [578]	validation-rmse:6.33018
# [579]	validation-rmse:6.33004
# [580]	validation-rmse:6.33004
# [581]	validation-rmse:6.32996
# [582]	validation-rmse:6.32991
# [583]	validation-rmse:6.32980
# [584]	validation-rmse:6.32971
# [585]	validation-rmse:6.32962
# [586]	validation-rmse:6.32942
# [587]	validation-rmse:6.32948
# [588]	validation-rmse:6.32953
# [589]	validation-rmse:6.32942
# [590]	validation-rmse:6.32938
# [591]	validation-rmse:6.32941
# [592]	validation-rmse:6.32939
# [593]	validation-rmse:6.32926
# [594]	validation-rmse:6.32937
# [595]	validation-rmse:6.32952
# [596]	validation-rmse:6.32957
# [597]	validation-rmse:6.32960
# [598]	validation-rmse:6.32966
# [599]	validation-rmse:6.32962
# [600]	validation-rmse:6.32955
# [601]	validation-rmse:6.32954
# [602]	validation-rmse:6.32949
# [603]	validation-rmse:6.32948
# [604]	validation-rmse:6.32943
# [605]	validation-rmse:6.32947
# [606]	validation-rmse:6.32954
# [607]	validation-rmse:6.32945
# [608]	validation-rmse:6.32948
# [609]	validation-rmse:6.32964
# [610]	validation-rmse:6.32971
# [611]	validation-rmse:6.32961
# [612]	validation-rmse:6.32958
# [613]	validation-rmse:6.32948
# [614]	validation-rmse:6.32952
# [615]	validation-rmse:6.32953
# [616]	validation-rmse:6.32954
# [617]	validation-rmse:6.32952
# [618]	validation-rmse:6.32932
# [619]	validation-rmse:6.32928
# [620]	validation-rmse:6.32939
# [621]	validation-rmse:6.32933
# [622]	validation-rmse:6.32917
# [623]	validation-rmse:6.32923
# [624]	validation-rmse:6.32917
# [625]	validation-rmse:6.32909
# [626]	validation-rmse:6.32921
# [627]	validation-rmse:6.32923
# [628]	validation-rmse:6.32920
# [629]	validation-rmse:6.32926
# [630]	validation-rmse:6.32908
# [631]	validation-rmse:6.32906
# [632]	validation-rmse:6.32904
# [633]	validation-rmse:6.32887
# [634]	validation-rmse:6.32887
# [635]	validation-rmse:6.32885
# [636]	validation-rmse:6.32882
# [637]	validation-rmse:6.32877
# [638]	validation-rmse:6.32878
# [639]	validation-rmse:6.32871
# [640]	validation-rmse:6.32856
# [641]	validation-rmse:6.32842
# [642]	validation-rmse:6.32840
# [643]	validation-rmse:6.32828
# [644]	validation-rmse:6.32826
# [645]	validation-rmse:6.32839
# [646]	validation-rmse:6.32836
# [647]	validation-rmse:6.32841
# [648]	validation-rmse:6.32832
# [649]	validation-rmse:6.32824
# [650]	validation-rmse:6.32829
# [651]	validation-rmse:6.32828
# [652]	validation-rmse:6.32822
# [653]	validation-rmse:6.32819
# [654]	validation-rmse:6.32816
# [655]	validation-rmse:6.32809
# [656]	validation-rmse:6.32806
# [657]	validation-rmse:6.32807
# [658]	validation-rmse:6.32792
# [659]	validation-rmse:6.32802
# [660]	validation-rmse:6.32792
# [661]	validation-rmse:6.32798
# [662]	validation-rmse:6.32796
# [663]	validation-rmse:6.32811
# [664]	validation-rmse:6.32814
# [665]	validation-rmse:6.32806
# [666]	validation-rmse:6.32808
# [667]	validation-rmse:6.32801
# [668]	validation-rmse:6.32816
# [669]	validation-rmse:6.32804
# [670]	validation-rmse:6.32819
# [671]	validation-rmse:6.32812
# [672]	validation-rmse:6.32807
# [673]	validation-rmse:6.32800
# [674]	validation-rmse:6.32799
# [675]	validation-rmse:6.32816
# [676]	validation-rmse:6.32818
# [677]	validation-rmse:6.32824
# [678]	validation-rmse:6.32824
# [679]	validation-rmse:6.32815
# [680]	validation-rmse:6.32821
# [681]	validation-rmse:6.32816
# [682]	validation-rmse:6.32808
# [683]	validation-rmse:6.32809
# [684]	validation-rmse:6.32806
# [685]	validation-rmse:6.32795
# [686]	validation-rmse:6.32788
# [687]	validation-rmse:6.32788
# [688]	validation-rmse:6.32782
# [689]	validation-rmse:6.32780
# [690]	validation-rmse:6.32779
# [691]	validation-rmse:6.32757
# [692]	validation-rmse:6.32761
# [693]	validation-rmse:6.32767
# [694]	validation-rmse:6.32762
# [695]	validation-rmse:6.32761
# [696]	validation-rmse:6.32750
# [697]	validation-rmse:6.32761
# [698]	validation-rmse:6.32770
# [699]	validation-rmse:6.32756
# [700]	validation-rmse:6.32762
# [701]	validation-rmse:6.32761
# [702]	validation-rmse:6.32771
# [703]	validation-rmse:6.32764
# [704]	validation-rmse:6.32759
# [705]	validation-rmse:6.32754
# [706]	validation-rmse:6.32754
# [707]	validation-rmse:6.32758
# [708]	validation-rmse:6.32752
# [709]	validation-rmse:6.32752
# [710]	validation-rmse:6.32756
# [711]	validation-rmse:6.32752
# [712]	validation-rmse:6.32727
# [713]	validation-rmse:6.32712
# [714]	validation-rmse:6.32719
# [715]	validation-rmse:6.32730
# [716]	validation-rmse:6.32735
# [717]	validation-rmse:6.32737
# [718]	validation-rmse:6.32740
# [719]	validation-rmse:6.32741
# [720]	validation-rmse:6.32744
# [721]	validation-rmse:6.32743
# [722]	validation-rmse:6.32742
# [723]	validation-rmse:6.32734
# [724]	validation-rmse:6.32756
# [725]	validation-rmse:6.32749
# [726]	validation-rmse:6.32752
# [727]	validation-rmse:6.32767
# [728]	validation-rmse:6.32775
# [729]	validation-rmse:6.32771
# [730]	validation-rmse:6.32765
# [731]	validation-rmse:6.32768
# [732]	validation-rmse:6.32759
# [733]	validation-rmse:6.32762
# [734]	validation-rmse:6.32755
# [735]	validation-rmse:6.32761
# [736]	validation-rmse:6.32748
# [737]	validation-rmse:6.32744
# [738]	validation-rmse:6.32740
# [739]	validation-rmse:6.32745
# [740]	validation-rmse:6.32744
# [741]	validation-rmse:6.32744
# [742]	validation-rmse:6.32748
# [743]	validation-rmse:6.32739
# [744]	validation-rmse:6.32739
# [745]	validation-rmse:6.32730
# [746]	validation-rmse:6.32749
# [747]	validation-rmse:6.32744
# [748]	validation-rmse:6.32744
# [749]	validation-rmse:6.32737
# [750]	validation-rmse:6.32740
# [751]	validation-rmse:6.32731
# [752]	validation-rmse:6.32728
# [753]	validation-rmse:6.32725
# [754]	validation-rmse:6.32723
# [755]	validation-rmse:6.32727
# [756]	validation-rmse:6.32713
# [757]	validation-rmse:6.32722
# [758]	validation-rmse:6.32726
# [759]	validation-rmse:6.32717
# [760]	validation-rmse:6.32715
# [761]	validation-rmse:6.32720
# [762]	validation-rmse:6.32730
# [763]	validation-rmse:6.32726
# /home/codespace/anaconda3/envs/exp-tracking/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [05:21:37] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/03/27 05:21:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
logged_model = 'runs:/e52d64c57a854c83b29bb398265fb3de/models_mlflow'
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model_xgboost=mlflow.xgboost.load_model(logged_model)
# Predict on a Pandas DataFrame.
y_pred=loaded_model_xgboost.predict(valid)

# %%
print(y_pred[:5])
print(y_val[:5])
# Out:
# [14.159118  6.87823  13.207436 25.13605   9.614906]
# [17.91666667  6.5        15.25       18.23333333  8.96666667]

# %% [markdown]
# HW Solution
